# %%
import mcstasscript as ms
import mcstasscript.jb_interface as ms_widget

import make_SANSsimpleSpheres
# %matplotlib widget

# %% [markdown]
# # Reflectometer

# %% [markdown]
# ![alt](SANSsimpleSpheres.png)

# %%
instrument = make_SANSsimpleSpheres.make()
ms_widget.show(instrument)
# Out:
# VBox(children=(VBox(children=(HBox(children=(Label(value='pinhole_rad', layout=Layout(height='32px', width='15…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
instrument.show_instrument()
